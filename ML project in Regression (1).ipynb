# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Students_Social_Media_Addiction[1].csv")

# %%
df
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 1             2   22    Male       Graduate       India
# 2             3   20  Female  Undergraduate         USA
# 3             4   18    Male    High School          UK
# 4             5   21    Male       Graduate      Canada
# ..          ...  ...     ...            ...         ...
# 700         701   20  Female  Undergraduate       Italy
# 701         702   23    Male       Graduate      Russia
# 702         703   21  Female  Undergraduate       China
# 703         704   24    Male       Graduate       Japan
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 1                      2.1            Twitter                           No
# 2                      6.0             TikTok                          Yes
# 3                      3.0            YouTube                           No
# 4                      4.5           Facebook                          Yes
# ..                     ...                ...                          ...
# 700                    4.7             TikTok                           No
# 701                    6.8          Instagram                          Yes
# 702                    5.6             WeChat                          Yes
# 703                    4.3            Twitter                           No
# 704                    6.2           Facebook                          Yes
#
#      Sleep_Hours_Per_Night  Mental_Health_Score Relationship_Status  \
# 0                      6.5                    6     In Relationship
# 1                      7.5                    8              Single
# 2                      5.0                    5         Complicated
# 3                      7.0                    7              Single
# 4                      6.0                    6     In Relationship
# ..                     ...                  ...                 ...
# 700                    7.2                    7     In Relationship
# 701                    5.9                    4              Single
# 702                    6.7                    6     In Relationship
# 703                    7.5                    8              Single
# 704                    6.3                    5              Single
#
#      Conflicts_Over_Social_Media  Addicted_Score
# 0                              3               8
# 1                              0               3
# 2                              4               9
# 3                              1               4
# 4                              2               7
# ..                           ...             ...
# 700                            2               5
# 701                            5               9
# 702                            3               7
# 703                            2               4
# 704                            4               8
#
# [705 rows x 13 columns]

# %%
df.shape
# Out:
# (705, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Student_ID                    705 non-null    int64
#  1   Age                           705 non-null    int64
#  2   Gender                        705 non-null    object
#  3   Academic_Level                705 non-null    object
#  4   Country                       705 non-null    object
#  5   Avg_Daily_Usage_Hours         705 non-null    float64
#  6   Most_Used_Platform            705 non-null    object
#  7   Affects_Academic_Performance  705 non-null    object
#  8   Sleep_Hours_Per_Night         705 non-null    float64
#  9   Mental_Health_Score           705 non-null    int64
#  10  Relationship_Status           705 non-null    object
#  11  Conflicts_Over_Social_Media   705 non-null    int64
#  12  Addicted_Score                705 non-null    int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 71.7+ KB

# %%
df.head()
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
#    Mental_Health_Score Relationship_Status  Conflicts_Over_Social_Media  \
# 0                    6     In Relationship                            3
# 1                    8              Single                            0
# 2                    5         Complicated                            4
# 3                    7              Single                            1
# 4                    6     In Relationship                            2
#
#    Addicted_Score
# 0               8
# 1               3
# 2               9
# 3               4
# 4               7

# %%
df.describe()
# Out:
#        Student_ID         Age  Avg_Daily_Usage_Hours  Sleep_Hours_Per_Night  \
# count  705.000000  705.000000             705.000000             705.000000
# mean   353.000000   20.659574               4.918723               6.868936
# std    203.660256    1.399217               1.257395               1.126848
# min      1.000000   18.000000               1.500000               3.800000
# 25%    177.000000   19.000000               4.100000               6.000000
# 50%    353.000000   21.000000               4.800000               6.900000
# 75%    529.000000   22.000000               5.800000               7.700000
# max    705.000000   24.000000               8.500000               9.600000
#
#        Mental_Health_Score  Conflicts_Over_Social_Media  Addicted_Score
# count           705.000000                   705.000000      705.000000
# mean              6.226950                     2.849645        6.436879
# std               1.105055                     0.957968        1.587165
# min               4.000000                     0.000000        2.000000
# 25%               5.000000                     2.000000        5.000000
# 50%               6.000000                     3.000000        7.000000
# 75%               7.000000                     4.000000        8.000000
# max               9.000000                     5.000000        9.000000

# %% [markdown]
# ## HANDLING THE NULL VALUES

# %%
df.isnull().sum()
# Out:
# Student_ID                      0
# Age                             0
# Gender                          0
# Academic_Level                  0
# Country                         0
# Avg_Daily_Usage_Hours           0
# Most_Used_Platform              0
# Affects_Academic_Performance    0
# Sleep_Hours_Per_Night           0
# Mental_Health_Score             0
# Relationship_Status             0
# Conflicts_Over_Social_Media     0
# Addicted_Score                  0
# dtype: int64

# %% [markdown]
# ## HANDLING THE OUTLIERS

# %%
#sns.boxplot(x="Area",data=df)

columns_to_plot = ['Age','Avg_Daily_Usage_Hours','Sleep_Hours_Per_Night','Mental_Health_Score',
                  'Conflicts_Over_Social_Media','Addicted_Score']

rows = 2  # 3 rows
cols = 3  # 3 columns

fig, axes = plt.subplots(rows, cols, figsize=(15, 10))

axes = axes.flatten()  # Flatten to a 1D list for easy indexing

for i, column in enumerate(columns_to_plot):
    sns.boxplot(x=df[column], ax=axes[i])
    axes[i].set_title(f'Boxplot for {column}')

plt.tight_layout()
plt.show()

# %%
sns.histplot(df["Avg_Daily_Usage_Hours"],kde=True)
# Out:
# <Axes: xlabel='Avg_Daily_Usage_Hours', ylabel='Count'>

# %%
#IQR- winsorization-Replacing the the values with most permissble values i..ee  lower and upper bounds

def replace_outliers(dataframe,feature):
    Q1=dataframe[feature].quantile(0.25)
    Q3=dataframe[feature].quantile(0.75)

    IQR=Q3-Q1

    upper_bound=Q3+1.5*IQR  
    lower_bound=Q1-1.5*IQR

    # capping-replacing all higher values with upper bound (75% percentile)
    dataframe[feature]=np.where(dataframe[feature]>upper_bound,upper_bound,dataframe[feature])
    # flooring -replace all lower values with lower bounf (25% percentile)
    dataframe[feature]=np.where(dataframe[feature]<lower_bound,lower_bound,dataframe[feature])

for col in ['Avg_Daily_Usage_Hours']:
    replace_outliers(df, col)

# %%
sns.boxplot(x="Avg_Daily_Usage_Hours",data=df)
# Out:
# <Axes: xlabel='Avg_Daily_Usage_Hours'>

# %% [markdown]
# ## FEATURE SELECTION

# %%
#df.corr() 
corr1=df[["Age","Avg_Daily_Usage_Hours","Sleep_Hours_Per_Night","Mental_Health_Score","Conflicts_Over_Social_Media","Addicted_Score"]].corr()
corr1
# Out:
#                                   Age  Avg_Daily_Usage_Hours  \
# Age                          1.000000              -0.113449
# Avg_Daily_Usage_Hours       -0.113449               1.000000
# Sleep_Hours_Per_Night        0.125265              -0.790532
# Mental_Health_Score          0.160278              -0.801290
# Conflicts_Over_Social_Media -0.184482               0.804771
# Addicted_Score              -0.166396               0.832127
#
#                              Sleep_Hours_Per_Night  Mental_Health_Score  \
# Age                                       0.125265             0.160278
# Avg_Daily_Usage_Hours                    -0.790532            -0.801290
# Sleep_Hours_Per_Night                     1.000000             0.707439
# Mental_Health_Score                       0.707439             1.000000
# Conflicts_Over_Social_Media              -0.677266            -0.893572
# Addicted_Score                           -0.764858            -0.945051
#
#                              Conflicts_Over_Social_Media  Addicted_Score
# Age                                            -0.184482       -0.166396
# Avg_Daily_Usage_Hours                           0.804771        0.832127
# Sleep_Hours_Per_Night                          -0.677266       -0.764858
# Mental_Health_Score                            -0.893572       -0.945051
# Conflicts_Over_Social_Media                     1.000000        0.933586
# Addicted_Score                                  0.933586        1.000000

# %%
# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr1, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Selected Features")
plt.show()

# %% [markdown]
# ## HYPOTHESIS TESTING

# %%
df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df["Academic_Level"].unique()
# Out:
# array(['Undergraduate', 'Graduate', 'High School'], dtype=object)

# %%
df["Country"].unique()
# Out:
# array(['Bangladesh', 'India', 'USA', 'UK', 'Canada', 'Australia',
#        'Germany', 'Brazil', 'Japan', 'South Korea', 'France', 'Spain',
#        'Italy', 'Mexico', 'Russia', 'China', 'Sweden', 'Norway',
#        'Denmark', 'Netherlands', 'Belgium', 'Switzerland', 'Austria',
#        'Portugal', 'Greece', 'Ireland', 'New Zealand', 'Singapore',
#        'Malaysia', 'Thailand', 'Vietnam', 'Philippines', 'Indonesia',
#        'Taiwan', 'Hong Kong', 'Turkey', 'Israel', 'UAE', 'Egypt',
#        'Morocco', 'South Africa', 'Nigeria', 'Kenya', 'Ghana',
#        'Argentina', 'Chile', 'Colombia', 'Peru', 'Venezuela', 'Ecuador',
#        'Uruguay', 'Paraguay', 'Bolivia', 'Costa Rica', 'Panama',
#        'Jamaica', 'Trinidad', 'Bahamas', 'Iceland', 'Finland', 'Poland',
#        'Romania', 'Hungary', 'Czech Republic', 'Slovakia', 'Croatia',
#        'Serbia', 'Slovenia', 'Bulgaria', 'Estonia', 'Latvia', 'Lithuania',
#        'Ukraine', 'Moldova', 'Belarus', 'Kazakhstan', 'Uzbekistan',
#        'Kyrgyzstan', 'Tajikistan', 'Armenia', 'Georgia', 'Azerbaijan',
#        'Cyprus', 'Malta', 'Luxembourg', 'Monaco', 'Andorra', 'San Marino',
#        'Vatican City', 'Liechtenstein', 'Montenegro', 'Albania',
#        'North Macedonia', 'Kosovo', 'Bosnia', 'Qatar', 'Kuwait',
#        'Bahrain', 'Oman', 'Jordan', 'Lebanon', 'Iraq', 'Yemen', 'Syria',
#        'Afghanistan', 'Pakistan', 'Nepal', 'Bhutan', 'Sri Lanka',
#        'Maldives'], dtype=object)

# %%
df["Most_Used_Platform"].unique()
# Out:
# array(['Instagram', 'Twitter', 'TikTok', 'YouTube', 'Facebook',
#        'LinkedIn', 'Snapchat', 'LINE', 'KakaoTalk', 'VKontakte',
#        'WhatsApp', 'WeChat'], dtype=object)

# %%
df["Affects_Academic_Performance"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df["Relationship_Status"].unique()
# Out:
# array(['In Relationship', 'Single', 'Complicated'], dtype=object)

# %%
#discreate,categorical data ==> Chi Square Test

from scipy.stats import chi2_contingency

# Assuming 'df' is your DataFrame

# List of categorical columns to test with 'Addicted_Score'
categorical_cols = ['Gender','Academic_Level','Country','Most_Used_Platform','Affects_Academic_Performance','Relationship_Status']

# Perform Chi-Square Test for each categorical column against 'Addicted_Score'
for col in categorical_cols:
    # Create the contingency table between the categorical column and 'Addicted_Score'
    table = pd.crosstab(df[col], df['Addicted_Score'])
    
    # Perform the Chi-Square test
    chi2_stat, p_val, dof, expected = chi2_contingency(table)
    
    # Print the result
    print(f"Chi-Square Test between {col} and Addicted_Score")
    print(f"Chi-Square Statistic: {chi2_stat}")
    print(f"P-value: {p_val :.4f}")
    
    # Interpretation of the p-value
    if p_val < 0.05:
        print(f"There is a significant association between {col} and Addicted_Score.")
    else:
        print(f"There is no significant association between {col} and Addicted_Score.")
    
    print("\n" + "="*50 + "\n")
# Out:
# Chi-Square Test between Gender and Addicted_Score
# Chi-Square Statistic: 42.60522358894429
# P-value: 0.0000
# There is a significant association between Gender and Addicted_Score.
#
# ==================================================
#
# Chi-Square Test between Academic_Level and Addicted_Score
# Chi-Square Statistic: 99.2076044669005
# P-value: 0.0000
# There is a significant association between Academic_Level and Addicted_Score.
#
# ==================================================
#
# Chi-Square Test between Country and Addicted_Score
# Chi-Square Statistic: 2399.8122758764302
# P-value: 0.0000
# There is a significant association between Country and Addicted_Score.
#
# ==================================================
#
# Chi-Square Test between Most_Used_Platform and Addicted_Score
# Chi-Square Statistic: 1088.234385301441
# P-value: 0.0000
# There is a significant association between Most_Used_Platform and Addicted_Score.
#
# ==================================================
#
# Chi-Square Test between Affects_Academic_Performance and Addicted_Score
# Chi-Square Statistic: 653.6095817113079
# P-value: 0.0000
# There is a significant association between Affects_Academic_Performance and Addicted_Score.
#
# ==================================================
#
# Chi-Square Test between Relationship_Status and Addicted_Score
# Chi-Square Statistic: 75.33670457127803
# P-value: 0.0000
# There is a significant association between Relationship_Status and Addicted_Score.
#
# ==================================================

# %% [markdown]
# ## ENCODING

# %%
from sklearn.preprocessing import OrdinalEncoder

encoder=OrdinalEncoder()

df["Gender"]=encoder.fit_transform(df[["Gender"]])
df["Academic_Level"]=encoder.fit_transform(df[["Academic_Level"]])
df["Country"]=encoder.fit_transform(df[["Country"]])
df["Most_Used_Platform"]=encoder.fit_transform(df[["Most_Used_Platform"]])
df["Affects_Academic_Performance"]=encoder.fit_transform(df[["Affects_Academic_Performance"]])
df["Relationship_Status"]=encoder.fit_transform(df[["Relationship_Status"]])
print(encoder.categories_)
# Out:
# [array(['Complicated', 'In Relationship', 'Single'], dtype=object)]

# %%
df
# Out:
#      Student_ID  Age  Gender  Academic_Level  Country  Avg_Daily_Usage_Hours  \
# 0             1   19     0.0             2.0     10.0                    5.2
# 1             2   22     1.0             0.0     39.0                    2.1
# 2             3   20     0.0             2.0    102.0                    6.0
# 3             4   18     1.0             1.0    101.0                    3.0
# 4             5   21     1.0             0.0     18.0                    4.5
# ..          ...  ...     ...             ...      ...                    ...
# 700         701   20     0.0             2.0     44.0                    4.7
# 701         702   23     1.0             0.0     82.0                    6.8
# 702         703   21     0.0             2.0     20.0                    5.6
# 703         704   24     1.0             0.0     46.0                    4.3
# 704         705   19     0.0             2.0     78.0                    6.2
#
#      Most_Used_Platform  Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0                   1.0                           1.0                    6.5
# 1                   7.0                           0.0                    7.5
# 2                   6.0                           1.0                    5.0
# 3                  11.0                           0.0                    7.0
# 4                   0.0                           1.0                    6.0
# ..                  ...                           ...                    ...
# 700                 6.0                           0.0                    7.2
# 701                 1.0                           1.0                    5.9
# 702                 9.0                           1.0                    6.7
# 703                 7.0                           0.0                    7.5
# 704                 0.0                           1.0                    6.3
#
#      Mental_Health_Score  Relationship_Status  Conflicts_Over_Social_Media  \
# 0                      6                  1.0                            3
# 1                      8                  2.0                            0
# 2                      5                  0.0                            4
# 3                      7                  2.0                            1
# 4                      6                  1.0                            2
# ..                   ...                  ...                          ...
# 700                    7                  1.0                            2
# 701                    4                  2.0                            5
# 702                    6                  1.0                            3
# 703                    8                  2.0                            2
# 704                    5                  2.0                            4
#
#      Addicted_Score
# 0                 8
# 1                 3
# 2                 9
# 3                 4
# 4                 7
# ..              ...
# 700               5
# 701               9
# 702               7
# 703               4
# 704               8
#
# [705 rows x 13 columns]

# %%
x=df.iloc[:, :-1] #All columns except the last (Except Target)

y=df.iloc[:, -1] #The last column (Target)

# %%
x
# Out:
#      Student_ID  Age  Gender  Academic_Level  Country  Avg_Daily_Usage_Hours  \
# 0             1   19     0.0             2.0     10.0                    5.2
# 1             2   22     1.0             0.0     39.0                    2.1
# 2             3   20     0.0             2.0    102.0                    6.0
# 3             4   18     1.0             1.0    101.0                    3.0
# 4             5   21     1.0             0.0     18.0                    4.5
# ..          ...  ...     ...             ...      ...                    ...
# 700         701   20     0.0             2.0     44.0                    4.7
# 701         702   23     1.0             0.0     82.0                    6.8
# 702         703   21     0.0             2.0     20.0                    5.6
# 703         704   24     1.0             0.0     46.0                    4.3
# 704         705   19     0.0             2.0     78.0                    6.2
#
#      Most_Used_Platform  Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0                   1.0                           1.0                    6.5
# 1                   7.0                           0.0                    7.5
# 2                   6.0                           1.0                    5.0
# 3                  11.0                           0.0                    7.0
# 4                   0.0                           1.0                    6.0
# ..                  ...                           ...                    ...
# 700                 6.0                           0.0                    7.2
# 701                 1.0                           1.0                    5.9
# 702                 9.0                           1.0                    6.7
# 703                 7.0                           0.0                    7.5
# 704                 0.0                           1.0                    6.3
#
#      Mental_Health_Score  Relationship_Status  Conflicts_Over_Social_Media
# 0                      6                  1.0                            3
# 1                      8                  2.0                            0
# 2                      5                  0.0                            4
# 3                      7                  2.0                            1
# 4                      6                  1.0                            2
# ..                   ...                  ...                          ...
# 700                    7                  1.0                            2
# 701                    4                  2.0                            5
# 702                    6                  1.0                            3
# 703                    8                  2.0                            2
# 704                    5                  2.0                            4
#
# [705 rows x 12 columns]

# %%
y
# Out:
# 0      8
# 1      3
# 2      9
# 3      4
# 4      7
#       ..
# 700    5
# 701    9
# 702    7
# 703    4
# 704    8
# Name: Addicted_Score, Length: 705, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42) #test _size=0.2-split 80 and 20 ..,random_state=42=>

# %% [markdown]
# ## SCALING

# %%
#scaling
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

x_train_scaled=scaler.fit_transform(x_train)
x_train_scaled

x_test_scaled=scaler.transform(x_test)

# %% [markdown]
# ## LINEAR REGRESSION

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test_scaled)

# %%
#testing accuracy
from sklearn.metrics import r2_score    
r2_score(y_test,y_pred)*100
# Out:
# 95.91673841063214

# %%
#training accuracy

y2_pred=model.predict(x_train_scaled)
print ("Accuracy is "), r2_score(y_train,y2_pred)*100
# Out:
# Accuracy is
# (None, 95.64559584976962)

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import Lasso, ElasticNet

# Parameter grid
param_grid = {
    'alpha': [0.01, 0.1, 1, 10, 100]  # Regularization strength
}
ridge = Ridge()
lasso = Lasso()
elastic = ElasticNet()

# Grid Search with cross-validation
grid_search = GridSearchCV(ridge, param_grid, cv=5, scoring='r2')
grid_search.fit(x_train_scaled, y_train)

best_ridge = grid_search.best_estimator_
print("Best alpha:", grid_search.best_params_['alpha'])

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVR  # support vector classification =because we using classification
model=SVR(kernel="rbf",C=100,gamma="auto", epsilon = 0.5,) #Rgularization-> parameters=kernel,c(kernel,c=10 r 1)
model
# Out:
# SVR(C=100, epsilon=0.5, gamma='auto')

# %%
final=model.fit(x_train_scaled,y_train)
final
# Out:
# SVR(C=100, epsilon=0.5, gamma='auto')

# %%
#testing accuracy

y_pred=model.predict(x_test_scaled)
accuracy=r2_score(y_test,y_pred)
print(f"Accuracy: {accuracy * 100 :2f}%")
# Out:
# Accuracy: 94.558212%

# %%
#training accuracy

y2_pred=model.predict(x_train_scaled)
print ("Accuracy is "), r2_score(y_train,y2_pred)*100
# Out:
# Accuracy is
# (None, 96.41409647263782)

# %%
#hyperparameter tunning(beore testing we can find accuracy which is the best)-cross validation(CV)
from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.1, 1, 10,100],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto'],
    'epsilon': [0.1, 0.2, 0.5]
}

grid_search = GridSearchCV(SVR(), param_grid, cv=5)

grid_search.fit(x_train_scaled, y_train)

print("Best parameters:", grid_search.best_params_)

# %% [markdown]
# ## KNN

# %%
#To find K
import math
math.sqrt(len(y_test))
# Out:
# 11.874342087037917

# %%
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor(n_neighbors=5, metric = 'euclidean',weights = 'distance')

# %%
model.fit(x_train_scaled,y_train)
# Out:
# KNeighborsRegressor(metric='euclidean', weights='distance')

# %%
y_pred=model.predict(x_test_scaled)
print(r2_score(y_test,y_pred)*100)
# Out:
# 97.69481434352745

# %%
y2_pred=model.predict(x_train_scaled)
print(r2_score(y_train,y2_pred)*100)
# Out:
# 100.0

# %%
#hyperparameter tunning(beore testing we can find accuracy which is the best)-cross validation(CV)

from sklearn.model_selection import GridSearchCV
param_grid= {
    'n_neighbors':[3,5,7,9,11],
    'metric':['euclidean','manhatten'],
    'weights': ['uniform', 'distance'],
}

grid_search = GridSearchCV(KNeighborsRegressor(), param_grid, cv=5)

grid_search.fit(x_train_scaled, y_train)

print(grid_search.best_params_)
# Out:
# {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'distance'}
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 50 fits failed out of a total of 100.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 50 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'metric' parameter of KNeighborsRegressor must be a str among {'l2', 'russellrao', 'canberra', 'p', 'cosine', 'hamming', 'jaccard', 'correlation', 'sokalsneath', 'euclidean', 'precomputed', 'minkowski', 'nan_euclidean', 'infinity', 'chebyshev', 'yule', 'seuclidean', 'braycurtis', 'l1', 'sqeuclidean', 'mahalanobis', 'dice', 'manhattan', 'sokalmichener', 'haversine', 'pyfunc', 'rogerstanimoto', 'cityblock'}, a callable or an instance of 'sklearn.metrics._dist_metrics.DistanceMetric'. Got 'manhatten' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [0.96928076 0.97359118 0.95934934 0.96997945 0.95459592 0.96842832
#  0.94862154 0.96583886 0.94483153 0.96365269        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan]
#   warnings.warn(

# %% [markdown]
# ## DECISION TREE

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state=42,criterion='squared_error', max_depth = 20, min_samples_leaf= 1, min_samples_split= 13)
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=20, min_samples_split=13, random_state=42)

# %%
y_pred=model.predict(x_test)
print(r2_score(y_test,y_pred)*100)
# Out:
# 98.16877566335693

# %%
y2_pred=model.predict(x_train)
print(r2_score(y_train,y2_pred)*100)
# Out:
# 99.48248966706248

# %%
# No gini,entropy for regression model

from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# Define parameter distributions for Randomized Search
param_dist = {
    'criterion': ['squared_error', 'friedman_mse', 'absolute_error'], # valid for regression
    'max_depth': [None, 5, 10, 20, 30],
    'min_samples_split': randint(2,5, 11),
    'min_samples_leaf': randint(1,2, 5),
    'max_features': [None, 'sqrt', 'log2']
}

# Initialize RandomizedSearchCV
random_search = RandomizedSearchCV(
    DecisionTreeRegressor(random_state=42),
    param_distributions=param_dist,
    n_iter=10,  # You can increase this for more exploration
    cv=5,
    random_state=42
)

# Fit on training data
random_search.fit(x_train, y_train)

# Print the best parameters found
print("Best parameters:", random_search.best_params_)
# Out:
# Best parameters: {'criterion': 'friedman_mse', 'max_depth': 20, 'max_features': None, 'min_samples_leaf': 6, 'min_samples_split': 13}

# %%
# BOOSTING

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score


base_estimator = DecisionTreeRegressor(max_depth=4)

# Initialize AdaBoost Regressor
ada_reg = AdaBoostRegressor(estimator=base_estimator,n_estimators=100,learning_rate=0.1,random_state=42)


ada_reg.fit(x_train, y_train)


y_pred = ada_reg.predict(x_test)


mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)*100

print(f"Mean Squared Error: {mse:.4f}")
print(f"R² Score: {r2:.4f}")
# Out:
# Mean Squared Error: 0.0587
# R² Score: 97.6523

# %% [markdown]
# ## RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(n_estimators=240 ,max_depth = None, max_features = 'sqrt', min_samples_leaf = 1, min_samples_split= 9,)
rf_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_features='sqrt', min_samples_split=9,
#                       n_estimators=240)

# %%
accuracy = rf_model.score(x_test, y_test)*100
print("Model Accurcy:",accuracy)
# Out:
# Model Accurcy: 98.24772119024057

# %%
accuracy1 = rf_model.score(x_train, y_train)*100
print("Model Accurcy:",accuracy1)
# Out:
# Model Accurcy: 99.32886046526988

# %%
## HYPERPARAMETER

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint


param_dist = {'n_estimators': randint(50,500),
            'max_depth': [None, 10, 20, 30],
            'min_samples_split': randint(2, 10),
            'min_samples_leaf': randint(1, 5),
            'max_features': ['auto', 'sqrt', 'log2']}

rf = RandomForestRegressor()

rand_search = RandomizedSearchCV(rf, param_distributions = param_dist,n_iter=5, cv=5,verbose=1, n_jobs=-1)

rand_search.fit(x_train, y_train)
print("Best Hyperparameters:")
print(rand_search.best_params_)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 10 fits failed out of a total of 25.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 4 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [0.97398404 0.98084891        nan        nan 0.98355595]
#   warnings.warn(
# Best Hyperparameters:
# {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 376}
