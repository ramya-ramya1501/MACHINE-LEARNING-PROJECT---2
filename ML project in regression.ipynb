# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("Balaji Fast Food Sales.csv")

# %%
df
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.head()
# Out:
#    order_id        date        item_name  item_type  item_price  quantity  \
# 0         1  07-03-2022         Aalopuri   Fastfood          20        13
# 1         2   8/23/2022          Vadapav   Fastfood          20        15
# 2         3  11/20/2022          Vadapav   Fastfood          20         1
# 3         4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4         5  10-02-2022  Sugarcane juice  Beverages          25         8
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                 260              NaN         Mr.        Night
# 1                 300             Cash         Mr.    Afternoon
# 2                  20             Cash         Mr.    Afternoon
# 3                 150           Online         Mr.        Night
# 4                 200           Online         Mr.      Evening

# %%
df.describe()
# Out:
#           order_id   item_price     quantity  transaction_amount
# count  1000.000000  1000.000000  1000.000000         1000.000000
# mean    500.500000    33.315000     8.162000          275.230000
# std     288.819436    14.921744     4.413075          204.402979
# min       1.000000    20.000000     1.000000           20.000000
# 25%     250.750000    20.000000     4.000000          120.000000
# 50%     500.500000    25.000000     8.000000          240.000000
# 75%     750.250000    50.000000    12.000000          360.000000
# max    1000.000000    60.000000    15.000000          900.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            1000 non-null   int64
#  1   date                1000 non-null   object
#  2   item_name           1000 non-null   object
#  3   item_type           1000 non-null   object
#  4   item_price          1000 non-null   int64
#  5   quantity            1000 non-null   int64
#  6   transaction_amount  1000 non-null   int64
#  7   transaction_type    893 non-null    object
#  8   received_by         1000 non-null   object
#  9   time_of_sale        1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.3+ KB

# %% [markdown]
# checking the null values

# %% [markdown]
# ## Handling the null values

# %%
df.isnull().sum()
# Out:
# order_id                0
# date                    0
# item_name               0
# item_type               0
# item_price              0
# quantity                0
# transaction_amount      0
# transaction_type      107
# received_by             0
# time_of_sale            0
# dtype: int64

# %%
df.isnull()
# Out:
#      order_id   date  item_name  item_type  item_price  quantity  \
# 0       False  False      False      False       False     False
# 1       False  False      False      False       False     False
# 2       False  False      False      False       False     False
# 3       False  False      False      False       False     False
# 4       False  False      False      False       False     False
# ..        ...    ...        ...        ...         ...       ...
# 995     False  False      False      False       False     False
# 996     False  False      False      False       False     False
# 997     False  False      False      False       False     False
# 998     False  False      False      False       False     False
# 999     False  False      False      False       False     False
#
#      transaction_amount  transaction_type  received_by  time_of_sale
# 0                 False              True        False         False
# ...

# %%
df2=df.dropna()
df2
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# 5           6  11/14/2022          Vadapav   Fastfood          20        10
# ..        ...         ...              ...        ...         ...       ...
# 991       992  10/21/2022         Sandwich   Fastfood          60         5
# 992       993   7/17/2022          Frankie   Fastfood          50         3
# 993       994  11-01-2022         Panipuri   Fastfood          20         2
# 994       995   6/18/2022  Sugarcane juice  Beverages          25         1
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
# ...

# %%
df2.isnull().sum()
# Out:
# order_id              0
# date                  0
# item_name             0
# item_type             0
# item_price            0
# quantity              0
# transaction_amount    0
# transaction_type      0
# received_by           0
# time_of_sale          0
# dtype: int64

# %% [markdown]
# # handling the outliers

# %%
sns.boxplot(x="quantity",data=df)
# Out:
# <Axes: xlabel='quantity'>

# %%
sns.boxplot(x="transaction_amount",data=df)
# Out:
# <Axes: xlabel='transaction_amount'>

# %%
sns.histplot(df["transaction_amount"],kde=True)
# Out:
# <Axes: xlabel='transaction_amount', ylabel='Count'>

# %%
# winsorization-Replacing the the values with most permissble values i..ee  lower and upper bounds

def replace_outliers(dataframe,feature):
    Q1=dataframe[feature].quantile(0.25)
    Q3=dataframe[feature].quantile(0.75)

    IQR=Q3-Q1

    upper_bound=Q3+1.5*IQR  
    lower_bound=Q1-1.5*IQR

    # capping-replacing all higher values with upper bound (75% percentile)
    dataframe[feature]=np.where(dataframe[feature]>upper_bound,upper_bound,dataframe[feature])
    # flooring -replace all lower values with lower bounf (25% percentile)
    dataframe[feature]=np.where(dataframe[feature]<lower_bound,lower_bound,dataframe[feature])

# %%
replace_outliers(df,"transaction_amount")

# %%
sns.boxplot(x="transaction_amount",data=df)
# Out:
# <Axes: xlabel='transaction_amount'>

# %% [markdown]
# # encoding

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder=OrdinalEncoder()#
df['transaction_amount']=encoder.fit_transform(df[['transaction_amount']])

# %%
print (encoder.categories_)
# Out:
# [array([ 20.,  25.,  40.,  50.,  60.,  75.,  80., 100., 120., 125., 140.,
#        150., 160., 175., 180., 200., 220., 225., 240., 250., 260., 275.,
#        280., 300., 320., 325., 350., 360., 375., 400., 420., 440., 450.,
#        480., 500., 520., 540., 550., 560., 600., 650., 660., 700., 720.])]

# %%
df.head(2)
# Out:
#    order_id        date item_name item_type  item_price  quantity  \
# 0         1  07-03-2022  Aalopuri  Fastfood          20        13
# 1         2   8/23/2022   Vadapav  Fastfood          20        15
#
#    transaction_amount transaction_type received_by time_of_sale
# 0                20.0              NaN         Mr.        Night
# 1                23.0             Cash         Mr.    Afternoon

# %%
x=df.iloc[:,:-1] #all columns except the last (target)
y=df.iloc[:,-1] # the last column (target)

# %%
x
# Out:
#      order_id        date        item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022         Aalopuri   Fastfood          20        13
# 1           2   8/23/2022          Vadapav   Fastfood          20        15
# 2           3  11/20/2022          Vadapav   Fastfood          20         1
# 3           4  02-03-2023  Sugarcane juice  Beverages          25         6
# 4           5  10-02-2022  Sugarcane juice  Beverages          25         8
# ..        ...         ...              ...        ...         ...       ...
# 995       996   3/19/2023          Frankie   Fastfood          50        10
# 996       997   9/20/2022         Sandwich   Fastfood          60         7
# 997       998   1/26/2023         Sandwich   Fastfood          60        13
# 998       999   8/27/2022         Panipuri   Fastfood          20         5
# 999      1000   5/29/2022         Aalopuri   Fastfood          20         3
#
#      transaction_amount transaction_type received_by
# ...

# %%
y
# Out:
# 0          Night
# 1      Afternoon
# 2      Afternoon
# 3          Night
# 4        Evening
#          ...
# 995      Evening
# 996      Evening
# 997      Evening
# 998    Afternoon
# 999     Midnight
# Name: time_of_sale, Length: 1000, dtype: object

# %%
#df.corr()
corr2=df[["order_id","item_price","quantity","transaction_amount"]].corr()
corr2
# Out:
#                     order_id  item_price  quantity  transaction_amount
# order_id            1.000000    0.037028  0.010345            0.034006
# item_price          0.037028    1.000000  0.050361            0.608779
# quantity            0.010345    0.050361  1.000000            0.786951
# transaction_amount  0.034006    0.608779  0.786951            1.000000

# %% [markdown]
# ## Hypothesis testing

# %%
df["item_name"].unique()
# Out:
# array(['Aalopuri', 'Vadapav', 'Sugarcane juice', 'Panipuri', 'Frankie',
#        'Sandwich', 'Cold coffee'], dtype=object)

# %%
df["item_type"].unique()
# Out:
# array(['Fastfood', 'Beverages'], dtype=object)

# %%
df["transaction_type"].unique()
# Out:
# array([nan, 'Cash', 'Online'], dtype=object)

# %%
df["received_by"].unique()
# Out:
# array(['Mr.', 'Mrs.'], dtype=object)

# %%
df["time_of_sale"].unique()
# Out:
# array(['Night', 'Afternoon', 'Evening', 'Morning', 'Midnight'],
#       dtype=object)

# %%
import pandas as pd
from scipy.stats import chi2_contingency, ttest_ind



# Convert categorical columns if needed
categorical_cols = ['item_name','item_type','transaction_type','received_by']
numerical_cols = ['order_id','item_price','quantity','transaction_amount']

# Function to perform chi-square test for categorical variables
def chi_square_test(df, column, target='time_of_sale'):
    table = pd.crosstab(df[column], df[target])
    chi2, p, dof, expected = chi2_contingency(table)
    return p

# Function to perform t-test for numerical variables
def t_test(df, column, target='time_of_sale'):
    group0 = df[df[target] == 0][column]
    group1 = df[df[target] == 1][column]
    t_stat, p = ttest_ind(group0, group1, nan_policy='omit')
    return p

# Run tests and store results
print("Categorical Features - Chi-Square Test")
for col in categorical_cols:
    p = chi_square_test(df, col)
    print(f"{col}: p-value = {p:.4f} => {'Significant' if p < 0.05 else 'Not Significant'}")

print("\nNumerical Features - T-Test")
for col in numerical_cols:
    p = t_test(df, col)
    print(f"{col}: p-value = {p:.4f} => {'Significant' if p < 0.05 else 'Not Significant'}")
# Out:
# Categorical Features - Chi-Square Test
# item_name: p-value = 0.5492 => Not Significant
# item_type: p-value = 0.3425 => Not Significant
# transaction_type: p-value = 0.7200 => Not Significant
# received_by: p-value = 0.1091 => Not Significant
#
# Numerical Features - T-Test
# order_id: p-value = nan => Not Significant
# item_price: p-value = nan => Not Significant
# quantity: p-value = nan => Not Significant
# transaction_amount: p-value = nan => Not Significant

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
encoder=OrdinalEncoder()

# %%
df["item_name"]=encoder.fit_transform(df[["item_name"]])
df["item_type"]=encoder.fit_transform(df[["item_type"]])
df["transaction_type"]=encoder.fit_transform(df[["transaction_type"]])
df["received_by"]=encoder.fit_transform(df[["received_by"]])
df["time_of_sale"]=encoder.fit_transform(df[["time_of_sale"]])

# %%
print(encoder.categories_)
# Out:
# [array(['Afternoon', 'Evening', 'Midnight', 'Morning', 'Night'],
#       dtype=object)]

# %% [markdown]
# ## Split,Train,Test

# %%
x=df.iloc[:, :-1] #All columns except the last (Except Target)

y=df.iloc[:, -1] #The last column (Target)

# %%
x
# Out:
#      order_id        date  item_name  item_type  item_price  quantity  \
# 0           1  07-03-2022        0.0        1.0          20        13
# 1           2   8/23/2022        6.0        1.0          20        15
# 2           3  11/20/2022        6.0        1.0          20         1
# 3           4  02-03-2023        5.0        0.0          25         6
# 4           5  10-02-2022        5.0        0.0          25         8
# ..        ...         ...        ...        ...         ...       ...
# 995       996   3/19/2023        2.0        1.0          50        10
# 996       997   9/20/2022        4.0        1.0          60         7
# 997       998   1/26/2023        4.0        1.0          60        13
# 998       999   8/27/2022        3.0        1.0          20         5
# 999      1000   5/29/2022        0.0        1.0          20         3
#
#      transaction_amount  transaction_type  received_by
# 0                  20.0               NaN          0.0
# ...

# %%
y
# Out:
# 0      4.0
# 1      0.0
# 2      0.0
# 3      4.0
# 4      1.0
#       ...
# 995    1.0
# 996    1.0
# 997    1.0
# 998    0.0
# 999    2.0
# Name: time_of_sale, Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#      order_id        date  item_name  item_type  item_price  quantity  \
# 29         30   1/28/2023        2.0        1.0          50         2
# 535       536  03-01-2023        5.0        0.0          25         7
# 695       696   2/23/2023        5.0        0.0          25         3
# 557       558  10-01-2022        3.0        1.0          20         5
# 836       837   5/19/2022        0.0        1.0          20         7
# ..        ...         ...        ...        ...         ...       ...
# 106       107  02-07-2023        4.0        1.0          60         4
# 270       271  05-03-2022        6.0        1.0          20        13
# 860       861   1/24/2023        5.0        0.0          25         8
# 435       436  01-05-2023        2.0        1.0          50        10
# 102       103   3/14/2023        1.0        0.0          40         8
#
#      transaction_amount  transaction_type  received_by
# 29                  7.0               0.0          1.0
# ...

# %%
y_train
# Out:
# 29     4.0
# 535    1.0
# 695    1.0
# 557    3.0
# 836    2.0
#       ...
# 106    0.0
# 270    1.0
# 860    4.0
# 435    2.0
# 102    2.0
# Name: time_of_sale, Length: 800, dtype: float64

# %% [markdown]
# ## Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
x_train_scaled=scaler.fit_transform(x_test)
x_train_scaled
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27644\1295791133.py in ?()
# ----> 1 x_train_scaled=scaler.fit_transform(x_test)
#       2 x_train_scaled
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     311     @wraps(f)
#     312     def wrapped(self, X, *args, **kwargs):
# --> 313         data_to_wrap = f(self, X, *args, **kwargs)
#     314         if isinstance(data_to_wrap, tuple):
#     315             # only wrap the first output for cross decomposition
#     316             return_tuple = (
#
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py in ?(self, X, y, **fit_params)
#    1094                 )
#    1095
#    1096         if y is None:
#    1097             # fit method of arity 1 (unsupervised transformation)
# ...
